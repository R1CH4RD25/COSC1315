# %% [markdown]
# # Lesson 01 — Your First Python Program (6:08–8:08)
#
# **Watch:** 6:08–8:08 of the video.
#
# **Goal:** Type along (don’t copy/paste) to learn how to print text in Python.
#
# **How to run in Colab:** Click a code cell and press **Shift+Enter**.
#
# ### 💡 What You Will Learn
#
# - Writing your first Python program using the `print()` function
# - Using single quotes (`'`) or double quotes (`"`) inside `print()`
# - Running your program from the menu or with keyboard shortcuts (Windows/Mac)
# - Viewing program results in the terminal window
# - Understanding that more advanced programs will later use a **GUI (Graphical User Interface)**
#
#
# _Tip: In Colab, you can collapse whole sections using the chevron next to the section headings below._

# %% [markdown]
# ## ▶️ Walk‑Along Tasks (6:08–8:08)
# _Follow these exactly as demonstrated in the video._

# %% [markdown]
# ### ✍️ Task 1 — Print `Hello, world!`
# Type the code exactly and run the cell.

# %%
# Type your code below:

# %% [markdown]
# **✅ Expected Output**
# ```
# Hello, world!
# ```

# %% [markdown]
# ### ✍️ Task 2 — Print your name
# Use either single `'` or double `"` quotes inside `print(...)`.

# %%
# Type your code below:

# %% [markdown]
# **✅ Expected Output (example)**
# ```
# Your Name
# ```

# %% [markdown]
# ### ✍️ Task 3 — Use single quotes
# Repeat Task 2 but **use single quotes** this time.

# %%
# Type your code below:

# %% [markdown]
# **✅ Expected Output (example)**
# ```
# Your Name
# ```

# %% [markdown]
# ### ✍️ Task 4 — Print a sentence with quotes inside
# Print the exact sentence below. Choose your quoting or escaping so it works.
#
# **Target sentence:**
# ```
# I’m learning "Python" today!
# ```

# %%
# Type your code below:

# %% [markdown]
# **✅ Expected Output**
# ```
# I’m learning "Python" today!
# ```

# %% [markdown]
# ## 🧪 Try It Yourself
# _Do these without looking back. Type them out._

# %% [markdown]
# ### 🧠 Try It 1 — School name
# Print exactly: `Woodson ISD`

# %%
# Type your code below:

# %% [markdown]
# **✅ Expected Output**
# ```
# Woodson ISD
# ```

# %% [markdown]
# ### 🧠 Try It 2 — Two lines
# Use **two** `print(...)` calls to produce **two** lines:
#
# ```
# Python
# is fun!
# ```

# %%
# Type your code below:

# %% [markdown]
# **✅ Expected Output**
# ```
# Python
# is fun!
# ```

# %% [markdown]
# ### 🧠 Try It 3 — Three times
# Print `Hello!` on **three separate lines**. (No loops yet—use three print calls.)

# %%
# Type your code below:

# %% [markdown]
# **✅ Expected Output**
# ```
# Hello!
# Hello!
# Hello!
# ```

# %% [markdown]
# ### 🧠 Try It 4 — Apostrophes and quotes
# Print exactly: `It’s Friday — "Go Tigers!"`

# %%
# Type your code below:

# %% [markdown]
# **✅ Expected Output**
# ```
# It’s Friday — "Go Tigers!"
# ```

# %% [markdown]
# ## 🐞 Debug It
# _Fix the broken code so it runs and matches the expected output._

# %% [markdown]
# ### 🧩 Debug 1 — Case & punctuation
# **Broken code:**
# ```python
# PrinT("Hello, world!)
# ```
# **Hints:** Python is case-sensitive (`print` must be lowercase), quotes must come in pairs, and parentheses must balance.

# %%
# FIX THE CODE BELOW so it prints Hello, world!
PrinT("Hello, world!)

# %% [markdown]
# **✅ Expected Output**
# ```
# Hello, world!
# ```

# %% [markdown]
# ### 🧩 Debug 2 — Quoting strings
# **Broken code:**
# ```python
# print("I’m learning "Python" today!")
# ```
# **Hint:** Either switch the outer quotes or escape the inner quotes.

# %%
# FIX THE CODE BELOW so it prints: I’m learning "Python" today!
print("I’m learning "Python" today!")

# %% [markdown]
# **✅ Expected Output**
# ```
# I’m learning "Python" today!
# ```

# %% [markdown]
# ---
# ## 📌 Key Concepts Recap
# - `print(...)` outputs text to the screen.
# - Python is **case-sensitive**: `print` is correct, `Print` is not.
# - Strings go in matching quotes: `'text'` or `"text"`.
# - Use escaping or alternate quotes when your string contains quotes.
