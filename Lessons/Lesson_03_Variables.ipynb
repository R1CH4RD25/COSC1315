# %% [markdown]
# # Lesson 03 — Variables (12:56–18:16)
#
# **Watch:** 12:56–18:16 of the video.
#
# **Goal:** Learn how to store values in variables and understand different data types in Python.
#
# **How to run in Colab:** Click a code cell and press **Shift+Enter**.
#
# ### 💡 What You Will Learn
# - What variables are and why they are important
# - How to assign values to variables using `=`
# - The difference between **integers** (whole numbers) and **floats** (decimal numbers)
# - How to store text values in **strings**
# - How to store true/false values in **booleans**
# - Python’s case sensitivity (e.g., `True` vs `true`)
# - Using underscores in variable names (e.g., `is_new_patient`)
# - Practicing with real-world data by modeling a patient record
#
# _Tip: In Colab, you can collapse whole sections using the chevron next to the section headings below._

# %% [markdown]
# ## ▶️ Walk‑Along Tasks (12:56–18:16)

# %% [markdown]
# ### ✍️ Task 1 — Create a variable and print it

# %%
# Type your code below:

# %% [markdown]
# **✅ Expected Output**
# ```
# 10
# ```

# %% [markdown]
# ### ✍️ Task 2 — Update the value of a variable

# %%
# Type your code below:

# %% [markdown]
# **✅ Expected Output**
# ```
# 20
# ```

# %% [markdown]
# ### ✍️ Task 3 — Store and print a float

# %%
# Type your code below:

# %% [markdown]
# **✅ Expected Output**
# ```
# 4.9
# ```

# %% [markdown]
# ### ✍️ Task 4 — Store and print a string

# %%
# Type your code below:

# %% [markdown]
# **✅ Expected Output**
# ```
# Mosh
# ```

# %% [markdown]
# ### ✍️ Task 5 — Store and print a boolean

# %%
# Type your code below:

# %% [markdown]
# **✅ Expected Output**
# ```
# True
# ```

# %% [markdown]
# ## 🧪 Try It Yourself

# %% [markdown]
# ### 🧠 Try It 1 — Patient record

# %%
# Type your code below:

# %% [markdown]
# **✅ Example Output**
# ```
# John Smith
# 20
# True
# ```

# %% [markdown]
# ### 🧠 Try It 2 — Experiment with variables

# %%
# Type your code below:

# %% [markdown]
# **✅ Example Output**
# ```
# Alice
# 17
# 3.14
# False
# ```

# %% [markdown]
# ### 🧠 Try It 3 — Debug integer and float variables
# The code below has **errors**. Fix them so the program runs and matches the expected output.

# %%
# Debug the code below:

price = "10
rating = 4,9
print(price
print(rating)
# Out:
#   File "/tmp/ipython-input-2064139052.py", line 3
#     price = "10
#             ^
# SyntaxError: unterminated string literal (detected at line 3)

# %% [markdown]
# **✅ Expected Output**
# ```
# 10
# 4.9
# ```

# %% [markdown]
# ### 🧠 Try It 4 — Debug patient record
# The code below has **errors**. Fix them so the program runs and matches the expected output.

# %%
# Debug the code below:

Name = john smith
age = Twenty
is_new = true

print(name)
print(Age)
print(Is_New)

# %% [markdown]
# **✅ Expected Output**
# ```
# John Smith
# 20
# True
# ```
