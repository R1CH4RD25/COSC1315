# %% [markdown]
# # Lesson 04 — Receiving Input (18:16–22:08)

# %% [markdown]
# ## 🎥 Watch
# **Clip:** 18:16–22:08
# **Focus:** Calling `input()` to receive user input and printing dynamic messages.

# %% [markdown]
# ## 🎯 Goal (Learning Objectives)
# - Call the built-in `input()` function to prompt the user.
# - Store the returned value in a variable.
# - Concatenate strings to create custom output.
# - Recognize that `"Hi " + name` is an expression.

# %% [markdown]
# ## 🧭 What You Will Learn
# - Prompt strings and why we add a trailing space.
# - Assigning input to variables.
# - Printing messages with variables.
# - Expressions with string concatenation.

# %% [markdown]
# ## 🧠 Key Terms (10)
# 1. Function  2. Call  3. Argument  4. Return Value  5. `input()`
# 6. `print()`  7. Variable  8. String  9. Concatenation  10. Expression

# %% [markdown]
# ## 💻 How to run in Colab
# - Press the **chevron ▶️** to open the Table of Contents.
# - Click the **play button ▷** on each code cell.
# - When a prompt appears, type your answer and press **Enter**.

# %% [markdown]
# ## 🚶 Walk-Along Tasks

# %% [markdown]
# ### 🥕 Task 1 — Ask for a name
# **Prompt:** Create a program that asks `What is your name? ` and stores it in a variable. Then print a confirmation message that shows exactly what the user typed.

# %%
# Type your code below:

# %% [markdown]
# ✅ **Expected Output (example)**
# ```
# What is your name? Mosh
# You entered: Mosh
# ```

# %% [markdown]
# ### 🥕 Task 2 — Say hello
# **Prompt:** Ask for the user's name, then print a greeting like `Hi Mosh` using string concatenation.

# %%
# Type your code below:
name = input("What is your name? ")
print("Hi " + name)
# Out:
# What is your name? Mosh
# Hi Mosh

# %% [markdown]
# ✅ **Expected Output (example)**
# ```
# What is your name? Mosh
# Hi Mosh
# ```

# %% [markdown]
# ### 🥕 Task 3 — Name + favorite color
# **Prompt:** Ask two questions: (1) `What is your name? ` and (2) `What is your favorite color? `
# Then print a sentence like `Mosh likes blue`.

# %%
# Type your code below:
name = input("What is your name? ")
color = input("What is your favorite color? ")
print(name + " likes " + color)
# Out:
# What is your name? Richard
# What is your favorite color? Gold
# Richard likes Gold

# %% [markdown]
# ✅ **Expected Output (example)**
# ```
# What is your name? Mosh
# What is your favorite color? Blue
# Mosh likes Blue
# ```

# %% [markdown]
# ## 📌 Try It Yourself

# %% [markdown]
# ### 🧠 TIY 1 — Favorite food (easy)
# **Prompt:** Ask for a name and favorite food. Print `"<name> loves <food>!"`.

# %%
# Type your code below:

# %% [markdown]
# ✅ **Example Output**
# ```
# What is your name? Ana
# What is your favorite food? tacos
# Ana loves tacos!
# ```

# %% [markdown]
# ### 🧠 TIY 2 — Pet preference (easy)
# **Prompt:** Ask for a name and whether they prefer cats or dogs. Print `"<name> prefers <animal>."`.

# %%
# Type your code below:

# %% [markdown]
# ✅ **Example Output**
# ```
# What is your name? Leo
# Do you prefer cats or dogs? dogs
# Leo prefers dogs.
# ```

# %% [markdown]
# ### 🧠 TIY 3 — Mood check (easy)
# **Prompt:** Ask for a name and how they are feeling today. Print `"<name> is feeling <mood> today."`.

# %%
# Type your code below:

# %% [markdown]
# ✅ **Example Output**
# ```
# What is your name? Jay
# How are you feeling today? excited
# Jay is feeling excited today.
# ```

# %% [markdown]
# ### 🧩 TIY 4 — Age in a sentence (harder)
# **Prompt:** Ask for a name and age. Print `"<name> is <age> years old."` (concatenation only).

# %%
# Type your code below:

# %% [markdown]
# ✅ **Example Output**
# ```
# What is your name? Ruth
# How old are you? 16
# Ruth is 16 years old.
# ```

# %% [markdown]
# ### 🧩 TIY 5 — Mini profile (harder)
# **Prompt:** Ask for a name, hometown, and a hobby. Print `"<name> is from <town> and enjoys <hobby>."`

# %%
# Type your code below:

# %% [markdown]
# ✅ **Example Output**
# ```
# What is your name? Omar
# What town are you from? Dallas
# What is a hobby you enjoy? basketball
# Omar is from Dallas and enjoys basketball.
# ```

# %% [markdown]
# ## 🐞 Debug the Bug

# %% [markdown]
# ### 🔧 Bug 1 — Missing quotes
# **Goal:** Make the program run. Do not change the behavior; fix the syntax.
#
# ```python
# # Broken starter:
# name = input(What is your name? )
# print("Hi " + name)
# ```

# %%
# Fix Bug 1 in this cell (edit the broken code):
name = input(What is your name? )
print("Hi " + name)
# Out:
#   File "/tmp/ipython-input-1687997809.py", line 2
#     name = input(What is your name? )
#                  ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ### 🔧 Bug 2 — Plus vs comma
# **Goal:** Make the greeting print correctly as one sentence.
#
# ```python
# # Broken starter:
# name = input("Name? ")
# print("Hi ", name + "!")
# ```

# %%
# Fix Bug 2 in this cell (edit the broken code):
name = input("Name? ")
print("Hi ", name + "!")

# %% [markdown]
# ### 🔧 Bug 3 — Variable name mismatch
# **Goal:** Ensure both variables exist and the sentence prints.
#
# ```python
# # Broken starter:
# color = input("Favorite color? ")
# print(name + " likes " + color)
# ```

# %%
# Fix Bug 3 in this cell (edit the broken code):
color = input("Favorite color? ")
print(name + " likes " + color)

# %% [markdown]
# ### 🔧 Bug 4 — Extra parenthesis
# **Goal:** Remove the syntax error and print the greeting.
#
# ```python
# # Broken starter:
# name = input("Name?"))
# print("Hi " + name)
# ```

# %%
# Fix Bug 4 in this cell (edit the broken code):
name = input("Name?"))
print("Hi " + name)

# %% [markdown]
# ### 🔧 Bug 5 — Missing space in prompt
# **Goal:** Make the prompt readable with a space after `?`.
#
# ```python
# # Broken starter:
# name = input("What is your name?")
# print("Hello " + name)
# ```

# %%
# Fix Bug 5 in this cell (edit the broken code):
name = input("What is your name?")
print("Hello " + name)
