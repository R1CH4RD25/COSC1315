# %% [markdown]
# # Project 01 — My Pet Info (Lessons 1–3 Review)
#
# **Time:** ~30 minutes · **Environment:** Google Colab (no new files needed)
#
# **Goal:** Practice `print()` and variables by introducing a real or imaginary pet with simple ASCII art.
#
# **How to run in Colab:** Click a code cell and press **Shift+Enter**.
#
# ### 💡 What You Will Use
# - `print()` with single or double quotes (Lesson 1)
# - Multi‑line output and simple ASCII art (Lesson 2)
# - Variables: strings, integers/floats, booleans (Lesson 3)
# - Bonus: string multiplication like `"*" * 20` (Lesson 2)
#
# _Tip: Collapse sections using the chevron ▾ on the left of headings._

# %% [markdown]
# ## ▶️ Step 1 — Banner with your name

# %% [markdown]
# Use `print()` to make a 3‑line banner: a line of stars, your name, another line of stars.
# Example:
# ```
# **********
# Sully
# **********
# ```
# Now, create **your own** banner below (don’t copy/paste the example).

# %%
# Type your code below:

# %% [markdown]
# ## ✍️ Step 2 — Define your pet variables

# %% [markdown]
# Create **four variables**:
# - `pet_name` (string)
# - `pet_type` (string)
# - `pet_age` (integer or float)
# - `is_new` (boolean `True` or `False`)
# Then print each one on its own line using `print()`.

# %%
# TODO: define variables
pet_name =
pet_type =
pet_age  =
is_new   =

# TODO: print each value on its own line
print()
print()
print()
print()

# %% [markdown]
# ## 🎨 Step 3 — Simple ASCII art

# %% [markdown]
# Draw your pet using 2–4 `print()` statements (like the Lesson 2 dog). Keep it simple!
# Example dog:
# ```
# o----
#    ||||
# ```

# %%
# Type your ASCII art below:

# %% [markdown]
# ## 🧾 Step 4 — Describe your pet using variables

# %% [markdown]
# Print 3–5 lines that describe your pet using the variables you created. For example:
# ```
# My pet's name is Buddy
# It is a dog
# Age: 3
# New pet: True
# ```

# %%
# Type your description below (use your variables):

# %% [markdown]
# ## ✨ Step 5 — Fancy separator line (bonus)

# %% [markdown]
# Use string multiplication to print a decorative line, e.g. `print("*" * 20)`.

# %%
# Print your separator line below:

# %% [markdown]
# ---
# ## 🧪 Debugging Challenges (Fix the code so it matches the output)

# %% [markdown]
# ### 🐞 Debug 1 — Quotes and parentheses

# %%
# Fix the code below so it prints exactly the Expected Output.

print("o----
print(   ||||")
print(Sully)

# %% [markdown]
# **✅ Expected Output**
# ```
# Sully
# o----
#    ||||
# ```

# %% [markdown]
# ### 🐞 Debug 2 — Variables and booleans

# %%
# Fix the code below so it runs and matches the Expected Output.

pet name = Buddy
pet_type = Dog
pet_age = three
Is_New = true

print("My pet's name is", pet_name)
print("It is a", pet type)
print("Age:", pet_age)
print("New pet:", is_new)

# %% [markdown]
# **✅ Expected Output**
# ```
# My pet's name is Buddy
# It is a Dog
# Age: 3
# New pet: True
# ```

# %% [markdown]
# ---
# ### ✅ Turn‑in Checklist
# - Banner with your name (3 lines)
# - Variables defined and printed (`pet_name`, `pet_type`, `pet_age`, `is_new`)
# - ASCII art printed with `print()`
# - Description using variables (3–5 lines)
# - Fancy separator line using string multiplication
# - Both debug tasks fixed to match expected outputs
