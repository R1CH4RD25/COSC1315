# %% [markdown]
# # Lesson 02 — How Python Code Gets Executed (8:08–11:20)
#
# **Watch:** 8:08–11:20 of the video.
#
# **Goal:** See how Python executes code **line by line from the top** using the **Python interpreter**, and practice building multi‑line output with `print()`.
#
# **How to run in Colab:** Click a code cell and press **Shift+Enter**.
#
# ### 💡 What You Will Learn
# - How Python executes code **line by line from the top**
# - The role of the **Python interpreter** in translating code into computer instructions
# - How to use multiple `print()` statements to build multi‑line output
# - Drawing simple shapes (like a dog) with text characters
# - Understanding the step‑by‑step flow of program execution
# - Practicing by creating your own ASCII‑style art with `print()`
#
# _Tip: In Colab, you can collapse sections using the chevron next to each heading below._

# %% [markdown]
# ## ▶️ Walk‑Along Tasks (8:08–11:20)

# %% [markdown]
# ### ✍️ Task 1 — Print your name again

# %%
# Type your code below:

# %% [markdown]
# **✅ Expected Output (example)**
# ```
# Sully
# ```

# %% [markdown]
# ### ✍️ Task 2 — Draw a dog head and body

# %%
# Type your code below:

# %% [markdown]
# **✅ Expected Output (example)**
# ```
# o----
# ```

# %% [markdown]
# ### ✍️ Task 3 — Draw dog legs under the body

# %%
# Type your code below:

# %% [markdown]
# **✅ Expected Output (example)**
# ```
#    ||||
# ```

# %% [markdown]
# ### ✍️ Task 4 — Full dog with name

# %%
# Type your code below:

# %% [markdown]
# **✅ Expected Output (example)**
# ```
# Sully
# o----
#    ||||
# ```

# %% [markdown]
# ## 🧪 Try It Yourself

# %% [markdown]
# ### 🧠 Try It 1 — Make **WHS** using at least 10 rows

# %%
# Type your code below:

# %% [markdown]
# **✅ Example Output (10+ rows)**
# ```
# W       W  H   H   SSSS
# W   W   W  H   H  S
# W   W   W  H   H  S
# W   W   W  H   H  S
# W  W W  W  HHHHH   SSS
# W W   W W  H   H      S
# WW     WW  H   H      S
# W       W  H   H      S
# W       W  H   H      S
# W       W  H   H  SSSS
# ```
# _Use at least 10 lines; adjust spacing for readability._

# %% [markdown]
# ### 🧠 Try It 2 — Create your **initials** using at least 10 rows

# %%
# Type your code below:

# %% [markdown]
# **✅ Example Output (for initials `RS`, 10 rows)**
# ```
# RRRRR     SSSSS
# R   R    S
# R   R   S
# RRRRR    S
# R R       SSSSS
# R  R           S
# R   R           S
# R    R          S
# R     R        S
# R      R  SSSSS
# ```
# _Replace `RS` with your own initials and keep to 10+ rows._

# %% [markdown]
# ### 🧠 Try It 3 — Debug: quotes and parentheses
# The code below has **errors**. Fix them so the output matches.

# %%
# Debug the code below:

print("o----
print(   ||||")
print(Sully)

# %% [markdown]
# **✅ Expected Output**
# ```
# Sully
# o----
#    ||||
# ```

# %% [markdown]
# ### 🧠 Try It 4 — Debug: quotes inside strings
# The code below has **errors** with quotes inside strings. Fix them so it prints the lines exactly as shown.

# %%
# Debug the code below:

print('He said, "Hello world!)
print("It's a dog: o----)
print(   |||| )

# %% [markdown]
# **✅ Expected Output**
# ```
# He said, "Hello world!"
# It's a dog: o----
#    ||||
# ```
